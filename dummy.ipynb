# %%
# Out:
# /home/clown2/anaconda3/envs/jax_lnn_312/lib/python3.12/pty.py:95: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# gpu
# E0422 09:47:34.780672  898691 pjrt_stream_executor_client.cc:3077] Execution of replica 0 failed: INTERNAL: jaxlib/gpu/solver_interface.cc:63: operation cublasSgetrfBatched(handle, n, a, lda, ipiv, info, batch) failed: cuBlas execution failed
# ---------------------------------------------------------------------------
# XlaRuntimeError                           Traceback (most recent call last)
# Cell In[3], line 179
#     176     return (params, opt_state, key, step+1), (gn, lr)
#     178 init_carry = (params, opt_state, key, 0)
# --> 179 (params, opt_state, _, _), (all_gns, all_lrs) = jax.jit(
#     180     lambda c: lax.scan(scan_step, c, None, length=total_steps)
#     181     )(init_carry)
#
# ...
