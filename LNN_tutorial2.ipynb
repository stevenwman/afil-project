# %%
import jax
import jax.numpy as jnp
import numpy as np
from jax.experimental.ode import odeint
import matplotlib.pyplot as plt
from functools import partial # reduces arguments to function by making some subset implicit

from jax.example_libraries import stax
from jax.example_libraries import optimizers

# visualization
import matplotlib.pyplot as plt
from matplotlib.patches import Circle
# from moviepy.video.io.ImageSequenceClip import ImageSequenceClip
from functools import partial
# import proglog
# from PIL import Image

from jax.lib import xla_bridge
print(xla_bridge.get_backend().platform)
# Out:
# gpu

# %%
def lagrangian(q, q_dot, m1, m2, l1, l2, g):
  t1, t2 = q     # theta 1 and theta 2
  w1, w2 = q_dot # omega 1 and omega 2

  # kinetic energy (T)
  T1 = 0.5 * m1 * (l1 * w1)**2
  T2 = 0.5 * m2 * ((l1 * w1)**2 + (l2 * w2)**2 +
					2 * l1 * l2 * w1 * w2 * jnp.cos(t1 - t2))
  T = T1 + T2
  
  # potential energy (V)
  y1 = -l1 * jnp.cos(t1)
  y2 = y1 - l2 * jnp.cos(t2)
  V = m1 * g * y1 + m2 * g * y2

  return T - V

def f_analytical(state, t=0, m1=1, m2=1, l1=1, l2=1, g=9.8):
  t1, t2, w1, w2 = state
  a1 = (l2 / l1) * (m2 / (m1 + m2)) * jnp.cos(t1 - t2)
  a2 = (l1 / l2) * jnp.cos(t1 - t2)
  f1 = -(l2 / l1) * (m2 / (m1 + m2)) * (w2**2) * jnp.sin(t1 - t2) - \
	  (g / l1) * jnp.sin(t1)
  f2 = (l1 / l2) * (w1**2) * jnp.sin(t1 - t2) - (g / l2) * jnp.sin(t2)
  g1 = (f1 - a1 * f2) / (1 - a1 * a2)
  g2 = (f2 - a2 * f1) / (1 - a1 * a2)
  return jnp.stack([w1, w2, g1, g2])

def equation_of_motion(lagrangian, state, t=None):
  q, q_t = jnp.split(state, 2)
  q_tt = (jnp.linalg.pinv(jax.hessian(lagrangian, 1)(q, q_t))
          @ (jax.grad(lagrangian, 0)(q, q_t)
             - jax.jacobian(jax.jacobian(lagrangian, 1), 0)(q, q_t) @ q_t))
  return jnp.concatenate([q_t, q_tt])

def solve_lagrangian(lagrangian, initial_state, **kwargs):
  # We currently run odeint on CPUs only, because its cost is dominated by
  # control flow, which is slow on GPUs.
  @partial(jax.jit, backend='cpu')
  def f(initial_state):
    return odeint(partial(equation_of_motion, lagrangian),
                  initial_state, **kwargs)
  return f(initial_state)

# # Double pendulum dynamics via the rewritten Euler-Lagrange
@partial(jax.jit, backend='cpu')
def solve_autograd(initial_state, times, m1=1, m2=1, l1=1, l2=1, g=9.8):
  L = partial(lagrangian, m1=m1, m2=m2, l1=l1, l2=l2, g=g)
  return solve_lagrangian(L, initial_state, t=times, rtol=1e-10, atol=1e-10)

# Double pendulum dynamics via analytical forces taken from Diego's blog
@partial(jax.jit, backend='cpu')
def solve_analytical(initial_state, times):
  return odeint(f_analytical, initial_state, t=times, rtol=1e-10, atol=1e-10)

def normalize_dp(state):
  # wrap generalized coordinates to [-pi, pi]
  return jnp.concatenate([(state[:2] + np.pi) % (2 * np.pi) - np.pi, state[2:]])
#   return state

def rk4_step(f, x, t, h):
  # one step of runge-kutta integration
  k1 = h * f(x, t)
  k2 = h * f(x + k1/2, t + h/2)
  k3 = h * f(x + k2/2, t + h/2)
  k4 = h * f(x + k3, t + h)
  return x + 1/6 * (k1 + 2 * k2 + 2 * k3 + k4)

# %%
time_step = 0.01
N = 1500
analytical_step = jax.jit(jax.vmap(partial(rk4_step, f_analytical, t=0.0, h=time_step)))

# x0 = np.array([-0.3*np.pi, 0.2*np.pi, 0.35*np.pi, 0.5*np.pi], dtype=np.float32)
x0 = np.array([3*np.pi/7, 3*np.pi/4, 0, 0], dtype=np.float32)
t = np.arange(N, dtype=np.float32) # time steps 0 to N
# %time x_train = jax.device_get(solve_analytical(x0, t)) # dynamics for first N time steps
# %time xt_train = jax.device_get(jax.vmap(f_analytical)(x_train)) # time derivatives of each state
# %time y_train = jax.device_get(analytical_step(x_train)) # analytical next step

noise = np.random.RandomState(0).randn(x0.size)
t_test = np.arange(N, 2*N, dtype=np.float32) # time steps N to 2N
# %time x_test = jax.device_get(solve_analytical(x0, t_test)) # dynamics for next N time steps
# %time xt_test = jax.device_get(jax.vmap(f_analytical)(x_test)) # time derivatives of each state
# %time y_test = jax.device_get(analytical_step(x_test)) # analytical next step
# Out:
# CPU times: user 12.9 s, sys: 286 ms, total: 13.2 s
# Wall time: 12.6 s
# CPU times: user 497 ms, sys: 22.5 ms, total: 520 ms
# Wall time: 839 ms
# CPU times: user 562 ms, sys: 38.2 ms, total: 601 ms
# Wall time: 708 ms
# CPU times: user 12.6 s, sys: 8.16 ms, total: 12.6 s
# Wall time: 12.6 s
# CPU times: user 21.7 ms, sys: 2.17 ms, total: 23.9 ms
# Wall time: 14.1 ms
# CPU times: user 748 μs, sys: 42 μs, total: 790 μs
# Wall time: 328 μs

# %%
train_permutation = jax.random.permutation(jax.random.PRNGKey(0), x_train.shape[0])
test_permutation = jax.random.permutation(jax.random.PRNGKey(1), x_test.shape[0])
x_train = x_train[train_permutation]
xt_train = xt_train[train_permutation]
y_train = y_train[train_permutation]

x_test = x_test[test_permutation]
xt_test = xt_test[test_permutation]
y_test = y_test[test_permutation]

# %%
plt.figure(figsize=(10,5))
plt.plot(xt_train[:,:], linestyle='None', marker='.')
plt.legend(['$q_1$', '$q_2$', '$\dot q_1$', '$\dot q_2$'])
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_130343/3682029270.py:3: SyntaxWarning: invalid escape sequence '\d'
#   plt.legend(['$q_1$', '$q_2$', '$\dot q_1$', '$\dot q_2$'])
# /tmp/ipykernel_130343/3682029270.py:3: SyntaxWarning: invalid escape sequence '\d'
#   plt.legend(['$q_1$', '$q_2$', '$\dot q_1$', '$\dot q_2$'])

# %%
# preprocess
train_vis = jax.vmap(normalize_dp)(x_train)
test_vis = jax.vmap(normalize_dp)(x_test)

vel_angle = lambda data:  (np.arctan2(data[:,3], data[:,2]) / np.pi + 1)/2
vel_color = lambda vangle: np.stack( [np.zeros_like(vangle), vangle, 1-vangle]).T
train_colors = vel_color(vel_angle(train_vis))
test_colors = vel_color(vel_angle(test_vis))

# plot
SCALE = 80 ; WIDTH = 0.006
plt.figure(figsize=[8,4], dpi=120)
plt.subplot(1,2,1)
plt.title("Train data") ; plt.xlabel(r'$\theta_1$') ; plt.ylabel(r'$\theta_2$')
plt.quiver(*train_vis.T, color=train_colors, scale=SCALE, width=WIDTH)

plt.subplot(1,2,2)
plt.title("Test data") ; plt.xlabel(r'$\theta_1$') ; plt.ylabel(r'$\theta_2$')
plt.quiver(*test_vis.T, color=test_colors, scale=SCALE, width=WIDTH)

plt.tight_layout() ; plt.show()

# %%
# replace the lagrangian with a parameteric model
def learned_lagrangian(params):
  def lagrangian(q, q_t):
    assert q.shape == (2,)
    state = normalize_dp(jnp.concatenate([q, q_t]))
    return jnp.squeeze(nn_forward_fn(params, state), axis=-1)
  return lagrangian

# define the loss of the model (MSE between predicted q, \dot q and targets)
@jax.jit
def loss(params, batch, time_step=None):
  state, targets = batch
  if time_step is not None:
    f = partial(equation_of_motion, learned_lagrangian(params))
    preds = jax.vmap(partial(rk4_step, f, t=0.0, h=time_step))(state)
  else:
    preds = jax.vmap(partial(equation_of_motion, learned_lagrangian(params)))(state)
  return jnp.mean((preds - targets) ** 2)

# build a neural network model
init_random_params, nn_forward_fn = stax.serial(
    stax.Dense(128),
    stax.Softplus,
    stax.Dense(128),
    stax.Softplus,
    stax.Dense(1),
)

# init_random_params, nn_forward_fn = stax.serial(
#     stax.Dense(256),
#     stax.Softplus,
#     stax.Dense(256),
#     stax.Softplus,
#     stax.Dense(256),
#     stax.Softplus,
#     stax.Dense(1),
# )

# %%
@jax.jit
def update_timestep(i, opt_state, batch):
  params = get_params(opt_state)
  return opt_update(i, jax.grad(loss)(params, batch, time_step), opt_state)

@jax.jit
def update_derivative(i, opt_state, batch):
  params = get_params(opt_state)
  return opt_update(i, jax.grad(loss)(params, batch, None), opt_state)

x_train = jax.device_put(jax.vmap(normalize_dp)(x_train))
y_train = jax.device_put(y_train)

x_test = jax.device_put(jax.vmap(normalize_dp)(x_test))
y_test = jax.device_put(y_test)

# %%
# %%time

rng = jax.random.PRNGKey(0)
_, init_params = init_random_params(rng, (-1, 4))

# numbers in comments denote stephan's settings
batch_size = 100
test_every = 10
num_batches = 1500

train_losses = []
test_losses = []

# adam w learn rate decay
opt_init, opt_update, get_params = optimizers.adam(
    lambda t: jnp.select([t < batch_size*(num_batches//3),
                          t < batch_size*(2*num_batches//3),
                          t > batch_size*(2*num_batches//3)],
                         [1e-3, 3e-4, 1e-4]))
opt_state = opt_init(init_params)

for iteration in range(batch_size*num_batches + 1):
  if iteration % batch_size == 0:
    params = get_params(opt_state)
    train_loss = loss(params, (x_train, xt_train))
    train_losses.append(train_loss)
    test_loss = loss(params, (x_test, xt_test))
    test_losses.append(test_loss)
    if iteration % (batch_size*test_every) == 0:
      print(f"iteration={iteration}, train_loss={train_loss:.6f}, test_loss={test_loss:.6f}")
  opt_state = update_derivative(iteration, opt_state, (x_train, xt_train))

params = get_params(opt_state)
# Out:
# iteration=0, train_loss=263.910309, test_loss=271.060699
# iteration=1000, train_loss=158.443604, test_loss=165.184784
# iteration=2000, train_loss=158.352646, test_loss=165.070404
# iteration=3000, train_loss=158.193832, test_loss=164.869492
# iteration=4000, train_loss=157.931763, test_loss=164.539627
# iteration=5000, train_loss=157.521744, test_loss=164.022842
# iteration=6000, train_loss=156.893265, test_loss=163.235672
# iteration=7000, train_loss=155.954285, test_loss=162.072556
# iteration=8000, train_loss=154.564087, test_loss=160.391983
# iteration=9000, train_loss=152.389893, test_loss=157.867706
# iteration=10000, train_loss=148.468796, test_loss=153.526596
# iteration=11000, train_loss=136.655518, test_loss=140.672806
# iteration=12000, train_loss=79.847748, test_loss=81.598732
# iteration=13000, train_loss=59.495708, test_loss=62.608719
# iteration=14000, train_loss=43.239754, test_loss=44.886345
# iteration=15000, train_loss=28.079353, test_loss=29.591194
# iteration=16000, train_loss=16.268326, test_loss=17.715691
# iteration=17000, train_loss=10.097809, test_loss=11.548740
# iteration=18000, train_loss=5.185984, test_loss=6.100955
# iteration=19000, train_loss=3.763781, test_loss=4.489109
# iteration=20000, train_loss=2.858424, test_loss=3.577118
# iteration=21000, train_loss=1.946976, test_loss=2.595049
# iteration=22000, train_loss=1.325784, test_loss=1.781270
# iteration=23000, train_loss=1.536585, test_loss=1.744840
# iteration=24000, train_loss=1.606135, test_loss=1.738796
# iteration=25000, train_loss=0.727091, test_loss=0.973501
# iteration=26000, train_loss=0.617446, test_loss=0.845118
# iteration=27000, train_loss=0.539934, test_loss=0.737943
# iteration=28000, train_loss=0.467492, test_loss=0.678693
# iteration=29000, train_loss=0.411440, test_loss=0.589295
# iteration=30000, train_loss=0.435631, test_loss=0.568129
# iteration=31000, train_loss=0.368276, test_loss=0.539823
# iteration=32000, train_loss=0.359857, test_loss=0.512614
# iteration=33000, train_loss=0.414009, test_loss=0.557071
# iteration=34000, train_loss=0.276022, test_loss=0.419576
# iteration=35000, train_loss=0.309253, test_loss=0.437701
# iteration=36000, train_loss=0.203260, test_loss=0.327325
# iteration=37000, train_loss=0.468532, test_loss=0.568150
# iteration=38000, train_loss=0.834170, test_loss=0.966720
# iteration=39000, train_loss=0.200943, test_loss=0.293680
# iteration=40000, train_loss=0.522347, test_loss=0.561980
# iteration=41000, train_loss=0.241821, test_loss=0.316451
# iteration=42000, train_loss=0.175071, test_loss=0.251443
# iteration=43000, train_loss=0.167085, test_loss=0.264031
# iteration=44000, train_loss=0.112968, test_loss=0.196395
# iteration=45000, train_loss=0.265206, test_loss=0.342349
# iteration=46000, train_loss=0.088534, test_loss=0.170077
# iteration=47000, train_loss=0.084688, test_loss=0.169031
# iteration=48000, train_loss=0.090649, test_loss=0.169276
# iteration=49000, train_loss=0.132985, test_loss=0.200695
# iteration=50000, train_loss=0.095180, test_loss=0.186523
# iteration=51000, train_loss=0.062843, test_loss=0.137265
# iteration=52000, train_loss=0.061582, test_loss=0.131178
# iteration=53000, train_loss=0.067402, test_loss=0.121779
# iteration=54000, train_loss=0.055558, test_loss=0.110068
# iteration=55000, train_loss=0.059713, test_loss=0.112527
# iteration=56000, train_loss=0.054491, test_loss=0.108714
# iteration=57000, train_loss=0.041818, test_loss=0.094530
# iteration=58000, train_loss=0.187405, test_loss=0.235525
# iteration=59000, train_loss=0.058639, test_loss=0.100459
# iteration=60000, train_loss=0.044519, test_loss=0.090041
# iteration=61000, train_loss=0.078062, test_loss=0.120416
# iteration=62000, train_loss=0.076406, test_loss=0.117999
# iteration=63000, train_loss=0.065980, test_loss=0.120486
# iteration=64000, train_loss=0.140187, test_loss=0.172569
# iteration=65000, train_loss=0.051904, test_loss=0.097634
# iteration=66000, train_loss=0.122355, test_loss=0.166896
# iteration=67000, train_loss=0.049219, test_loss=0.089252
# iteration=68000, train_loss=0.095234, test_loss=0.121594
# iteration=69000, train_loss=0.087854, test_loss=0.120897
# iteration=70000, train_loss=0.122829, test_loss=0.168873
# iteration=71000, train_loss=0.035532, test_loss=0.082782
# iteration=72000, train_loss=0.036224, test_loss=0.079169
# iteration=73000, train_loss=0.183516, test_loss=0.227917
# iteration=74000, train_loss=0.060964, test_loss=0.103990
# iteration=75000, train_loss=0.030937, test_loss=0.073367
# iteration=76000, train_loss=0.042856, test_loss=0.081700
# iteration=77000, train_loss=0.026648, test_loss=0.068394
# iteration=78000, train_loss=0.026628, test_loss=0.064987
# iteration=79000, train_loss=0.040387, test_loss=0.080888
# iteration=80000, train_loss=0.038565, test_loss=0.072948
# iteration=81000, train_loss=0.025996, test_loss=0.063208
# iteration=82000, train_loss=0.042150, test_loss=0.080443
# iteration=83000, train_loss=0.087162, test_loss=0.128728
# iteration=84000, train_loss=0.026222, test_loss=0.063249
# iteration=85000, train_loss=0.022958, test_loss=0.059574
# iteration=86000, train_loss=0.053041, test_loss=0.087096
# iteration=87000, train_loss=0.035504, test_loss=0.074192
# iteration=88000, train_loss=0.033033, test_loss=0.069111
# iteration=89000, train_loss=0.027240, test_loss=0.056779
# iteration=90000, train_loss=0.024593, test_loss=0.055939
# iteration=91000, train_loss=0.032936, test_loss=0.066729
# iteration=92000, train_loss=0.026593, test_loss=0.058768
# iteration=93000, train_loss=0.030513, test_loss=0.062852
# iteration=94000, train_loss=0.042573, test_loss=0.080980
# iteration=95000, train_loss=0.052767, test_loss=0.078893
# iteration=96000, train_loss=0.023469, test_loss=0.056363
# iteration=97000, train_loss=0.100509, test_loss=0.133413
# iteration=98000, train_loss=0.021646, test_loss=0.056855
# iteration=99000, train_loss=0.025217, test_loss=0.061658
# iteration=100000, train_loss=0.059113, test_loss=0.088432
# iteration=101000, train_loss=0.017891, test_loss=0.050626
# iteration=102000, train_loss=0.018990, test_loss=0.052099
# iteration=103000, train_loss=0.017246, test_loss=0.047024
# iteration=104000, train_loss=0.018880, test_loss=0.046561
# iteration=105000, train_loss=0.019813, test_loss=0.047967
# iteration=106000, train_loss=0.018698, test_loss=0.049202
# iteration=107000, train_loss=0.029576, test_loss=0.055608
# iteration=108000, train_loss=0.019705, test_loss=0.053627
# iteration=109000, train_loss=0.023828, test_loss=0.049925
# iteration=110000, train_loss=0.021419, test_loss=0.045573
# iteration=111000, train_loss=0.041809, test_loss=0.070940
# iteration=112000, train_loss=0.016022, test_loss=0.046135
# iteration=113000, train_loss=0.018785, test_loss=0.048267
# iteration=114000, train_loss=0.029784, test_loss=0.055451
# iteration=115000, train_loss=0.028653, test_loss=0.054643
# iteration=116000, train_loss=0.015459, test_loss=0.043906
# iteration=117000, train_loss=0.015441, test_loss=0.045602
# iteration=118000, train_loss=0.018536, test_loss=0.046326
# iteration=119000, train_loss=0.016025, test_loss=0.043612
# iteration=120000, train_loss=0.015671, test_loss=0.043839
# iteration=121000, train_loss=0.017327, test_loss=0.043155
# iteration=122000, train_loss=0.020420, test_loss=0.046372
# iteration=123000, train_loss=0.015699, test_loss=0.044121
# iteration=124000, train_loss=0.015678, test_loss=0.042217
# iteration=125000, train_loss=0.015407, test_loss=0.039567
# iteration=126000, train_loss=0.014632, test_loss=0.040710
# iteration=127000, train_loss=0.015238, test_loss=0.041594
# iteration=128000, train_loss=0.015432, test_loss=0.043529
# iteration=129000, train_loss=0.014069, test_loss=0.038041
# iteration=130000, train_loss=0.020493, test_loss=0.046752
# iteration=131000, train_loss=0.013546, test_loss=0.038258
# iteration=132000, train_loss=0.017362, test_loss=0.041235
# iteration=133000, train_loss=0.022903, test_loss=0.047297
# iteration=134000, train_loss=0.021506, test_loss=0.045594
# iteration=135000, train_loss=0.017878, test_loss=0.044205
# iteration=136000, train_loss=0.027657, test_loss=0.049317
# iteration=137000, train_loss=0.028167, test_loss=0.048468
# iteration=138000, train_loss=0.015578, test_loss=0.041897
# iteration=139000, train_loss=0.023847, test_loss=0.052048
# iteration=140000, train_loss=0.021202, test_loss=0.048798
# iteration=141000, train_loss=0.019214, test_loss=0.045553
# iteration=142000, train_loss=0.015058, test_loss=0.040574
# iteration=143000, train_loss=0.014849, test_loss=0.037515
# iteration=144000, train_loss=0.025715, test_loss=0.050488
# iteration=145000, train_loss=0.015177, test_loss=0.038974
# iteration=146000, train_loss=0.019903, test_loss=0.040618
# iteration=147000, train_loss=0.014624, test_loss=0.039342
# iteration=148000, train_loss=0.047401, test_loss=0.065737
# iteration=149000, train_loss=0.039255, test_loss=0.058969
# iteration=150000, train_loss=0.015695, test_loss=0.043019
# CPU times: user 2min 26s, sys: 21.2 s, total: 2min 47s
# Wall time: 2min 5s

# %%
plt.figure(figsize=(8, 3.5), dpi=120)
plt.plot(train_losses, label='Train loss')
plt.plot(test_losses, label='Test loss')
plt.yscale('log')
plt.ylim(None, 200)
plt.title('Losses over training')
plt.xlabel("Train step") ; plt.ylabel("Mean squared error")
plt.legend() ; plt.show()

# %%
xt_pred = jax.vmap(partial(equation_of_motion, learned_lagrangian(params)))(x_test)

fig, axes = plt.subplots(1, 2, figsize=(6, 3), dpi=120)
axes[0].scatter(xt_test[:, 2], xt_pred[:, 2], s=6, alpha=0.2)
axes[0].set_title('Predicting $\dot q$')
axes[0].set_xlabel('$\dot q$ actual')
axes[0].set_ylabel('$\dot q$ predicted')
axes[1].scatter(xt_test[:, 3], xt_pred[:, 3], s=6, alpha=0.2)
axes[1].set_title('Predicting $\ddot q$')
axes[1].set_xlabel('$\ddot q$ actual')
axes[1].set_ylabel('$\ddot q$ predicted')
plt.tight_layout()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# <>:7: SyntaxWarning: invalid escape sequence '\d'
# <>:9: SyntaxWarning: invalid escape sequence '\d'
# <>:10: SyntaxWarning: invalid escape sequence '\d'
# <>:11: SyntaxWarning: invalid escape sequence '\d'
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# <>:7: SyntaxWarning: invalid escape sequence '\d'
# <>:9: SyntaxWarning: invalid escape sequence '\d'
# <>:10: SyntaxWarning: invalid escape sequence '\d'
# <>:11: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_107300/394263438.py:5: SyntaxWarning: invalid escape sequence '\d'
#   axes[0].set_title('Predicting $\dot q$')
# /tmp/ipykernel_107300/394263438.py:6: SyntaxWarning: invalid escape sequence '\d'
#   axes[0].set_xlabel('$\dot q$ actual')
# /tmp/ipykernel_107300/394263438.py:7: SyntaxWarning: invalid escape sequence '\d'
#   axes[0].set_ylabel('$\dot q$ predicted')
# /tmp/ipykernel_107300/394263438.py:9: SyntaxWarning: invalid escape sequence '\d'
#   axes[1].set_title('Predicting $\ddot q$')
# /tmp/ipykernel_107300/394263438.py:10: SyntaxWarning: invalid escape sequence '\d'
#   axes[1].set_xlabel('$\ddot q$ actual')
# /tmp/ipykernel_107300/394263438.py:11: SyntaxWarning: invalid escape sequence '\d'
#   axes[1].set_ylabel('$\ddot q$ predicted')

# %%
# make a meshgrid of possible angles
angle_range = -np.pi + 2 * np.pi * np.arange(100)/100
x_scanned = np.stack(np.meshgrid(angle_range, angle_range, [0.0], [0.0], indexing='ij'), axis=-1).reshape(-1, 4)

# %time xt_actual = jax.vmap(f_analytical)(x_scanned) # actual time derivatives
# Out:
# CPU times: user 38.2 ms, sys: 3.8 ms, total: 42 ms
# Wall time: 29.1 ms

# %%
# %time xt_predicted = jax.vmap(partial(equation_of_motion, learned_lagrangian(params)))(x_scanned) # predicted time derivatives
# Out:
# CPU times: user 6.06 s, sys: 154 ms, total: 6.21 s
# Wall time: 3.21 s

# %%
import xarray
dataarray = xarray.DataArray(np.stack([xt_actual.reshape(100, 100, 4),
                                       xt_predicted.reshape(100, 100, 4)]),
                             dims=['model', 'theta1', 'theta2', 'time_derivative'],
                             coords={'model': ['actual', 'predicted'], 'theta1': angle_range, 'theta2': angle_range})

dataarray.isel(time_derivative=2).plot.contourf(cmap='RdBu_r', levels=31, col='model', x='theta1', y='theta2', vmin=-10, vmax=10)
print("Colorscale is \dot theta1")
plt.show()

# Calculate the difference (actual - predicted)
difference = dataarray.sel(model='actual') - dataarray.sel(model='predicted')
# Plot the difference for time_derivative=2
difference.isel(time_derivative=2).plot.contourf(levels=31, x='theta1', y='theta2', vmin=-10, vmax=10,cmap='RdBu_r')

plt.title('Difference (Actual - Predicted) for $\\dot{\\theta}_1$')
# plt.colorbar(label='Difference in $\\dot{\\theta}_1$')
plt.show()
# Out:
# Colorscale is \dot theta1
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_107300/1882305494.py:8: SyntaxWarning: invalid escape sequence '\d'
#   print("Colorscale is \dot theta1")
